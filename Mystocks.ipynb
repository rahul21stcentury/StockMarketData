# %%
import pandas as pd
import numpy as np

# %%
sheet=pd.read_csv('Mystocksheet.csv')

# %%
sheet
# Out:
#                 Name Purchase_Date Sold_Date     Cost   Return  Number
# 0       FIRST SOURCE    06/04/2021  07/04/21   119.95   116.90       1
# 1          JSW Steel    06/04/2021  08/04/21   526.55   567.75       4
# 2   Adani Enterprise    07/04/2021  12/04/21  1230.25  1148.35       1
# 3        Adani Green    06/04/2021  09/04/21  1183.35  1131.25       1
# 4         Sun Pharma    07/04/2021  13/04/21   619.50   621.00       1
# 5                ITC    07/04/2021  12/04/21   215.00   209.00       5
# 6              Cipla    08/04/2021  13/04/21   845.20   898.00       2
# 7      Tech mahindra    09/04/2021  12/04/21  1025.40  1039.60       2
# 8              Wipro    09/04/2021  12/04/21   443.65   440.75       3
# 9      Cadila Health    12/04/2021  13/04/21   521.15   495.00       4
# 10          HCL tech    19/04/2021       NaN   999.85   970.50       3
# 11        Sun Pharma    19/04/2021       NaN   647.30   647.20       5
# ...

# %%
sheet['Gain']=sheet['Number']*(sheet['Return']-sheet['Cost'])

# %%
sheet
# Out:
#                 Name Purchase_Date Sold_Date     Cost   Return  Number  \
# 0       FIRST SOURCE    06/04/2021  07/04/21   119.95   116.90       1
# 1          JSW Steel    06/04/2021  08/04/21   526.55   567.75       4
# 2   Adani Enterprise    07/04/2021  12/04/21  1230.25  1148.35       1
# 3        Adani Green    06/04/2021  09/04/21  1183.35  1131.25       1
# 4         Sun Pharma    07/04/2021  13/04/21   619.50   621.00       1
# 5                ITC    07/04/2021  12/04/21   215.00   209.00       5
# 6              Cipla    08/04/2021  13/04/21   845.20   898.00       2
# 7      Tech mahindra    09/04/2021  12/04/21  1025.40  1039.60       2
# 8              Wipro    09/04/2021  12/04/21   443.65   440.75       3
# 9      Cadila Health    12/04/2021  13/04/21   521.15   495.00       4
# 10          HCL tech    19/04/2021       NaN   999.85   970.50       3
# 11        Sun Pharma    19/04/2021       NaN   647.30   647.20       5
# ...

# %%
sheet['Gain'].sum()
# Out:
# 125.1000000000003
